# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Life expectancy.csv")

# %%
df
# Out:
#              Entity  Year  Life expectancy
# 0         Australia  1802        34.049999
# 1         Australia  1803        34.049999
# 2         Australia  1804        34.049999
# 3         Australia  1805        34.049999
# 4         Australia  1806        34.049999
# ...             ...   ...              ...
# 3248  United States  2012        78.940002
# 3249  United States  2013        78.959999
# 3250  United States  2014        78.940002
# 3251  United States  2015        78.870003
# 3252  United States  2016        78.860001
#
# [3253 rows x 3 columns]

# %%
df["Entity"].unique()
# Out:
# array(['Australia', 'Brazil', 'Canada', 'China', 'France', 'Germany',
#        'India', 'Italy', 'Japan', 'Mexico', 'Russia', 'Spain',
#        'Switzerland', 'United Kingdom', 'United States'], dtype=object)

# %%
len(df["Entity"].unique())
# Out:
# 15

# %%
min(df["Year"])
# Out:
# 1800

# %%
max(df["Year"])
# Out:
# 2016

# %%
fig, axes = plt.subplots(nrows=5, ncols=3, sharex=True, sharey=True, figsize=(15,15))
axes_list = [item for sublist in axes for item in sublist] 

for countryname, selection in df.groupby("Entity"):
    ax = axes_list.pop(0)
    selection.plot(x='Year', y='Life expectancy', label=countryname, ax=ax, legend=False, clip_on=False)
    ax.set_title(countryname)
    ax.tick_params(
        which='both',
        bottom='off',
        left='off',
        right='off',
        top='off'
    )
    ax.grid(linewidth=0.25)
    ax.set_xlim((1800, 2016))
    ax.set_xlabel("")
    ax.set_xticks(range(1800, 2016, 50))
    ax.spines['left'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

plt.tight_layout()
fig.savefig("life_expectancy.jpg")
